# %%
# Task 1.
# Import libraries
import pandas as pd
import numpy as np

# Import data

students = pd.read_csv('students.csv')
students.head()
students.notnull().sum()
# Out:
# gender                1000
# parental_education    1000
# test_prep_course      1000
# math_score            1000
# reading_score         1000
# writing_score         1000
# dtype: int64

# %%
# More female or male
print(students.gender.value_counts())
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
# Average score
students.mean()
# Out:
# /var/folders/xh/2ng5p2655msgdgw_rhkmql1m0000gn/T/ipykernel_4931/3161043836.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   students.mean()
# math_score       66.089
# reading_score    69.169
# writing_score    68.054
# dtype: float64

# %%
# Perfect student
students[(students.math_score == 100) & (students.reading_score == 100) & (students.writing_score == 100)]
# Out:
#      gender  parental_education test_prep_course  math_score  reading_score  \
# 458  female   bachelor's degree             none         100            100
# 916    male   bachelor's degree        completed         100            100
# 962  female  associate's degree             none         100            100
#
#      writing_score
# 458            100
# 916            100
# 962            100

# %%
# Average score with and without prep_course
average_prep = students[students.test_prep_course == 'completed'].math_score.mean()
print('Average score of students with test preparation course:', average_prep)

average_no_prep = students[students.test_prep_course == 'none'].math_score.mean()
print('Average score of students without test preparation course:', average_no_prep)
# Out:
# Average score of students with test preparation course: 69.69553072625699
# Average score of students without test preparation course: 64.0778816199377

# %%
# Task 2.
# Load the data
salary = pd.read_csv('salary.csv')
salary.head()
# Out:
#    experience_years   age  salary
# 0               1.1   NaN   39343
# 1               1.3  24.0   46205
# 2               1.5  28.7   37731
# 3               NaN  31.0   43525
# 4               2.2   NaN   39891

# %%
# Filling missing values
salary.fillna({'experience_years': 3}, inplace = True)
salary.age.fillna(salary.age.mean(), inplace = True)
salary.describe()
# Out:
#        experience_years        age         salary
# count         30.000000  30.000000      30.000000
# mean           4.890000  31.216000   76003.000000
# std            2.724265   3.377683   27414.429785
# min            1.100000  24.000000   37731.000000
# 25%            3.000000  29.225000   56720.750000
# 50%            4.000000  31.216000   65237.000000
# 75%            6.600000  33.800000  100544.750000
# max           10.500000  38.000000  122391.000000

# %%
# Checking correlation
# Correlation between salary and experience is much higher than between salary and age
# so experince seem to be more related to salary
salary.corr()
# Out:
#                   experience_years       age    salary
# experience_years          1.000000  0.532501  0.834603
# age                       0.532501  1.000000  0.519637
# salary                    0.834603  0.519637  1.000000

# %%
# Average age of high salary employees

salary_bins = [0, 55000, 90000, 125000]

salary_names = ['Low', 'Medium', 'High']

salary['salary_cat'] = pd.cut(salary.salary, salary_bins, labels = salary_names)

print(salary.salary_cat.value_counts())

salary[salary.salary_cat == 'High'].age.mean()
# Out:
# Medium    13
# High      11
# Low        6
# Name: salary_cat, dtype: int64
# 33.37418181818182

# %%
# Task 3. 
# Load data
movies = pd.read_csv('movies.csv',sep = ',',index_col = 0)
movies.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/xh/2ng5p2655msgdgw_rhkmql1m0000gn/T/ipykernel_4931/4002781027.py in <module>
#       1 # Task 3.
#       2 # Load data
# ----> 3 movies = pd.read_csv('movies.csv',sep = ',',index_col = 0)
#       4 movies.head()
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'movies.csv'

# %%
# Remove movies with less than 100 votes

movies = movies[movies.vote_count >= 100]
movies.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/xh/2ng5p2655msgdgw_rhkmql1m0000gn/T/ipykernel_4931/3012006456.py in <module>
#       1 # Remove movies with less than 100 votes
#       2
# ----> 3 movies = movies[movies.vote_count >= 100]
#       4 movies.shape
#
# NameError: name 'movies' is not defined

# %%
# 3rd most frequent original language
# Japan is in the third position
movies.original_language.value_counts()[:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/xh/2ng5p2655msgdgw_rhkmql1m0000gn/T/ipykernel_4931/646374754.py in <module>
#       1 # 3rd most frequent original language
#       2 # Japan is in the third position
# ----> 3 movies.original_language.value_counts()[:5]
#
# NameError: name 'movies' is not defined

# %%
# Finnish movies
# Two movies, highest rated is The man without the past

movies[movies.original_language == 'fi']

# %%
# Average for french and spanish movies
# Average for French movies is slightly higher

print(movies[movies.original_language == 'fr'].vote_average.mean())
print(movies[movies.original_language == 'es'].vote_average.mean())

# %%
# Most frequent vote category
# Average vote between 5 and 7.5 is the most frequent

vote_bins = [-0.01, 2.5, 5, 7.5, 10]

movies['vote'] = pd.cut(movies.vote_average, vote_bins)

movies.vote.value_counts()
